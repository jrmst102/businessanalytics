# %%
# Read the file

import pandas as pd
df = pd.read_csv('compact_suv_r.csv')

# %%
# Display the top records
df.head()
# Out:
#      Make     Model  Overall Score Recommended Owner Satisfaction  \
# 0  Subaru  Forester             84         Yes                  B
# 1   Honda       CRV             83         Yes                  A
# 2  Toyota      Rav4             81         Yes                  A
# 3  Nissan     Rogue             73         Yes                  B
# 4   Mazda      CX-5             71         Yes                  A
#
#    Overall Miles Per Gallon  Acceleration (0-60) Sec
# 0                        26                      8.7
# 1                        27                      8.6
# 2                        24                      9.3
# 3                        24                      9.5
# 4                        24                      8.6

# %%
# Display the bottom records
df.tail()
# Out:
#          Make     Model  Overall Score Recommended Owner Satisfaction  \
# 10  Chevrolet   Equinox             63          No                  C
# 11    Hyundai    Tuscon             57          No                  C
# 12        GMC   Terrain             57          No                  C
# 13      Jeep   Cherokee             55          No                  D
# 14      Jeep    Compass             50          No                  C
#
#     Overall Miles Per Gallon  Acceleration (0-60) Sec
# 10                        31                     10.1
# 11                        26                      8.4
# 12                        22                      7.2
# 13                        22                     10.9
# 14                        24                      9.8

# %%
# Display the file, warning: be careful with large files
df
# Out:
#           Make           Model  Overall Score Recommended Owner Satisfaction  \
# 0       Subaru        Forester             84         Yes                  B
# 1        Honda             CRV             83         Yes                  A
# 2       Toyota            Rav4             81         Yes                  A
# 3       Nissan           Rogue             73         Yes                  B
# 4        Mazda            CX-5             71         Yes                  A
# 5          Kia        Sportage             71         Yes                  B
# 6         Ford          Escape             69         Yes                  C
# 7   Volkswagen  Tiguan Limited             67          No                  C
# 8   Volkswagen          Tiguan             65          No                  B
# 9   Mitsubishi       Outlander             63          No                  C
# 10   Chevrolet         Equinox             63          No                  C
# ...

# %%
# Visualize the dataframe size
df.shape
# Out:
# (15, 7)

# %%
# Display how many unique values are in the Make column

df.Make.nunique()
# Out:
# 13

# %%
# Display the unique values in the Make column

df.Make.unique()
# Out:
# array(['Subaru', 'Honda', 'Toyota', 'Nissan', 'Mazda', 'Kia', 'Ford',
#        'Volkswagen', 'Mitsubishi', 'Chevrolet', 'Hyundai', 'GMC', 'Jeep '],
#       dtype=object)

# %%
# Display all the rows where Make == 'Volkswagen'
df[df.Make == 'Volkswagen']
# Out:
#          Make           Model  Overall Score Recommended Owner Satisfaction  \
# 7  Volkswagen  Tiguan Limited             67          No                  C
# 8  Volkswagen          Tiguan             65          No                  B
#
#    Overall Miles Per Gallon  Acceleration (0-60) Sec
# 7                        21                      8.5
# 8                        25                     10.3

# %%
# Display all the rows where Make == 'Jeep'
df[df.Make == 'Jeep']
# Out:
# Empty DataFrame
# Columns: [Make, Model, Overall Score, Recommended, Owner Satisfaction, Overall Miles Per Gallon, Acceleration (0-60) Sec]
# Index: []

# %%
# Display all the rows where Make == 'Jeep'
df[df.Make == 'Jeep ']
# Out:
#      Make     Model  Overall Score Recommended Owner Satisfaction  \
# 13  Jeep   Cherokee             55          No                  D
# 14  Jeep    Compass             50          No                  C
#
#     Overall Miles Per Gallon  Acceleration (0-60) Sec
# 13                        22                     10.9
# 14                        24                      9.8

# %%
# Display all the rows where Make == 'Jeep'
df[df.Make.str.strip() == 'Jeep']
# Out:
#      Make     Model  Overall Score Recommended Owner Satisfaction  \
# 13  Jeep   Cherokee             55          No                  D
# 14  Jeep    Compass             50          No                  C
#
#     Overall Miles Per Gallon  Acceleration (0-60) Sec
# 13                        22                     10.9
# 14                        24                      9.8

# %%
# Change Owner Satisfaction for Ford from 'C' to 'D'
df.loc[df['Make'] == 'Ford', 'Owner Satisfaction'] = 'D'
df
# Out:
#           Make           Model  Overall Score Recommended Owner Satisfaction  \
# 0       Subaru        Forester             84         Yes                  B
# 1        Honda             CRV             83         Yes                  A
# 2       Toyota            Rav4             81         Yes                  A
# 3       Nissan           Rogue             73         Yes                  B
# 4        Mazda            CX-5             71         Yes                  A
# 5          Kia        Sportage             71         Yes                  B
# 6         Ford          Escape             69         Yes                  D
# 7   Volkswagen  Tiguan Limited             67          No                  C
# 8   Volkswagen          Tiguan             65          No                  B
# 9   Mitsubishi       Outlander             63          No                  C
# 10   Chevrolet         Equinox             63          No                  C
# ...

# %%
# Rename column 'Acceleration (0-60) Sec' to 'Acceleration'

df.rename(columns={'Acceleration (0-60) Sec':'Acceleration'}, inplace=True)
df
# Out:
#           Make           Model  Overall Score Recommended Owner Satisfaction  \
# 0       Subaru        Forester             84         Yes                  B
# 1        Honda             CRV             83         Yes                  A
# 2       Toyota            Rav4             81         Yes                  A
# 3       Nissan           Rogue             73         Yes                  B
# 4        Mazda            CX-5             71         Yes                  A
# 5          Kia        Sportage             71         Yes                  B
# 6         Ford          Escape             69         Yes                  D
# 7   Volkswagen  Tiguan Limited             67          No                  C
# 8   Volkswagen          Tiguan             65          No                  B
# 9   Mitsubishi       Outlander             63          No                  C
# 10   Chevrolet         Equinox             63          No                  C
# ...

# %%
#Plot overall score versus overall miles per gallon

import matplotlib.pyplot as plt

plt.plot(df['Overall Score'], df['Overall Miles Per Gallon'])
plt.xlabel('Overall Score')
plt.ylabel('Overall MPG')
plt.title('Overall Score vs Overall MPG')
plt.show()
