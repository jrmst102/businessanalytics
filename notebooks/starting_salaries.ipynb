# %%
# Read and display the file startingsalaries.csv

import pandas as pd
df = pd.read_csv('startingsalaries.csv')
df.head()
# Out:
#    Graduate  Monthly Starting Salary ($)  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0       1.0                       5850.0         NaN         NaN         NaN
# 1       2.0                       5950.0         NaN         NaN         NaN
# 2       3.0                       6050.0         NaN         NaN         NaN
# 3       4.0                       5880.0         NaN         NaN         NaN
# 4       5.0                       5755.0         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
# Perform descriptive statistics on Starting Salary ($)

df['Monthly Starting Salary ($)'].describe()
# Out:
# count      12.000000
# mean     5940.000000
# std       165.652978
# min      5710.000000
# 25%      5872.500000
# 50%      5905.000000
# 75%      5975.000000
# max      6325.000000
# Name: Monthly Starting Salary ($), dtype: float64

# %%
# List the columns
df.columns
# Out:
# Index(['Graduate', 'Monthly Starting Salary ($)', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
# Rename column 'Monthly Starting Salary ($)'
df.rename(columns={'Monthly Starting Salary ($)':'Salary'}, inplace=True)
df.head()
# Out:
#    Graduate  Salary  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       1.0  5850.0         NaN         NaN         NaN         NaN
# 1       2.0  5950.0         NaN         NaN         NaN         NaN
# 2       3.0  6050.0         NaN         NaN         NaN         NaN
# 3       4.0  5880.0         NaN         NaN         NaN         NaN
# 4       5.0  5755.0         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# Delete column 'Unnamed: 2'

df = df.drop('Unnamed: 2', axis=1)
df.head()
# Out:
#    Graduate  Salary  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0       1.0  5850.0         NaN         NaN         NaN         NaN
# 1       2.0  5950.0         NaN         NaN         NaN         NaN
# 2       3.0  6050.0         NaN         NaN         NaN         NaN
# 3       4.0  5880.0         NaN         NaN         NaN         NaN
# 4       5.0  5755.0         NaN         NaN         NaN         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#... < write your code here >
df.head()
# Out:
#    Graduate  Salary
# 0       1.0  5850.0
# 1       2.0  5950.0
# 2       3.0  6050.0
# 3       4.0  5880.0
# 4       5.0  5755.0

# %%
# Create a histogram of 'Salary'

import matplotlib.pyplot as plt
plt.hist(df['Salary'])
plt.show()

# %%
# Save the file as 'startingsalaries_clean.csv
df.to_csv('startingsalaries_clean.csv')
df.head()
# Out:
#    Graduate  Salary
# 0       1.0  5850.0
# 1       2.0  5950.0
# 2       3.0  6050.0
# 3       4.0  5880.0
# 4       5.0  5755.0
