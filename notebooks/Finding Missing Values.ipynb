# %% [markdown]
# ##Business Analytics and Data Visualization
# ###Prof. Jose Mendoza
#
# Chapter 4 - Exercise 23
#
# File: bickley_r.csv

# %%
# Read Bickley_r.csv

import pandas as pd
df = pd.read_csv('bickley_r.csv')
df.head()
# Out:
#      First       Last                    Email Address   GPA
# 0      Roy      Hardy         Roy.Hardy@montgomery.edu  3.64
# 1    Dylan     Davila       Dylan.Davila@cleeghorn.edu  3.95
# 2     Sara   Bradford     Sara.Bradford@montgomery.edu  4.00
# 3  Melissa  Davenport  Melissa.Davenport@cleeghorn.edu  3.71
# 4    Henry      Trejo       Henry.Trejo@montgomery.edu  3.74

# %%
#Check for missing values in GPA field

print('There are ', df['GPA'].isnull().sum(), ' missing values in GPA')
# Out:
# There are  2  missing values in GPA

# %%
# Print a list with missing values
missing_values = df[df['GPA'].isnull()]
print(missing_values)
# Out:
#       First     Last              Email Address  GPA
# 88   George  Gardner  George.Gardner@benson.edu  NaN
# 155    Eric    Cohen   Eric.Cohen@cleeghorn.edu  NaN
