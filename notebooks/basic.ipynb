# %%
z = 3

# %%
z
# Out:
# 3

# %%
y = -2

# %%
x = [1, 2, 6]

# %%
# prompt: Assign W to a vector of integers between -1 and 4

z = 3
z
y = -2
x = [1, 2, 6]
W = [-1, 0, 1, 2, 3, 4]

# %%
v = z ** y

# %%
v
# Out:
# 0.1111111111111111

# %%
# Math is a mathematical library
import math
w = math.sqrt(z)
w
# Out:
# 1.7320508075688772

# %% [markdown]
# ## Hello
