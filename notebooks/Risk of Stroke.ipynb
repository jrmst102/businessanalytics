# %% [markdown]
# ##Business Analytics and Data Visualization
# ###Prof. Jose Mendoza
#
# Chapter 4 - Exercise 26
#
# File: ahanonsmokers_r.csv, ahasmokers_r.csv

# %%
# Import files
import pandas as pd

nonsmokers = pd.read_csv('ahanonsmokers_r.csv')
smokers = pd.read_csv('ahasmokers_r.csv')

# %%
# Examining Non Smokers
nonsmokers.head()
# Out:
#    Subject  Risk  Age  Systolic  Diastolic
# 0        1    12   57       152         95
# 1        2    24   67       163        105
# 2        3    13   58       155         96
# 3        4    28   59       196        124
# 4        5    31   78       120         83

# %%
# Examining Smokers
smokers.head()
# Out:
#    Subject  Risk  Age  Systolic  Diastolic
# 0      105    56   46       177        120
# 1      106    51   76       189        126
# 2      107    18   56       155        101
# 3      108    37   80       135         94
# 4      109    36   70       173        116

# %%
# Create a new column for Non Smokers
nonsmokers['smoker'] = 0
nonsmokers.head()
# Out:
#    Subject  Risk  Age  Systolic  Diastolic  smoker
# 0        1    12   57       152         95       0
# 1        2    24   67       163        105       0
# 2        3    13   58       155         96       0
# 3        4    28   59       196        124       0
# 4        5    31   78       120         83       0

# %%
# Create a new columm for Smokers
smokers['smoker'] = 1
smokers.head()
# Out:
#    Subject  Risk  Age  Systolic  Diastolic  smoker
# 0      105    56   46       177        120       1
# 1      106    51   76       189        126       1
# 2      107    18   56       155        101       1
# 3      108    37   80       135         94       1
# 4      109    36   70       173        116       1

# %%
# Concatenate both datasets
respondents = pd.concat([smokers,nonsmokers],axis=0)
respondents.head()
# Out:
#    Subject  Risk  Age  Systolic  Diastolic  smoker
# 0      105    56   46       177        120       1
# 1      106    51   76       189        126       1
# 2      107    18   56       155        101       1
# 3      108    37   80       135         94       1
# 4      109    36   70       173        116       1

# %%
# Save respondents as respondents.csv
respondents.to_csv('respondents.csv', index=False)
