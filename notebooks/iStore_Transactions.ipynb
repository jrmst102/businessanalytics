# %% [markdown]
# **Business Analytics and Data Visualization**
#
# Prof Jose Mendoza
#
# Chapter 6 - Exercise 37
#
# File: apple_stacked.csv
#
#
#
# > Note: This notebook assumes that the file breakfast.csv is located in Google Drive, in a folder named 'Data'. *

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# %%
# Read data file from the Data folder

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/Data/apple_stacked.csv')
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       Customer          Label
# 0            1       Cellular
# 1            1           64GB
# 2            1       Speakers
# 3            2  RetinaDisplay
# 4            2           16GB
# ...        ...            ...
# 5414      1996         Stylus
# 5415      1997           16GB
# 5416      1998           16GB
# 5417      1999           32GB
# 5418      2000           16GB
#
# [5419 rows x 2 columns]

# %%
# Examine which unique values we are dealing with
df['Label'].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['Cellular', '64GB', 'Speakers', 'RetinaDisplay', '16GB', '32GB',
#        'Case', 'Stand', 'Stylus', 'CameraKit', 'WirelessKeyboard',
#        'PlugBug'], dtype=object)

# %%
# Prepare the data for Association Rules

df2 = pd.crosstab(df['Customer'], df['Label'])
df2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Label     16GB  32GB  64GB  CameraKit  Case  Cellular  PlugBug  RetinaDisplay  \
# Customer
# 1            0     0     1          0     0         1        0              0
# 2            1     0     0          0     0         0        0              1
# 3            1     0     0          0     0         0        0              0
# 4            0     1     0          0     1         1        0              1
# 5            0     1     0          0     0         0        0              0
# ...        ...   ...   ...        ...   ...       ...      ...            ...
# 1996         0     1     0          0     0         0        1              0
# 1997         1     0     0          0     0         0        0              0
# 1998         1     0     0          0     0         0        0              0
# 1999         0     1     0          0     0         0        0              0
# 2000         1     0     0          0     0         0        0              0
#
# Label     Speakers  Stand  Stylus  WirelessKeyboard
# Customer
# 1                1      0       0                 0
# 2                0      0       0                 0
# 3                0      0       0                 0
# 4                1      0       0                 0
# 5                1      0       0                 0
# ...            ...    ...     ...               ...
# 1996             1      1       1                 1
# 1997             0      0       0                 0
# 1998             0      0       0                 0
# 1999             0      0       0                 0
# 2000             0      0       0                 0
#
# [2000 rows x 12 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Hot Encode the data in case there is more than one transaction per customer, per item
def encode(item_freq):
    res = 0
    if item_freq > 0:
        res = 1
    return res

basket_input = df2.applymap(encode)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# build the Apriori algorithm
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

frequent_itemsets = apriori(basket_input, min_support=0.001, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift")
rules.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#    antecedents  consequents  antecedent support  consequent support  support  \
# 0     (Stylus)       (16GB)              0.1085              0.4750   0.0530
# 1       (16GB)     (Stylus)              0.4750              0.1085   0.0530
# 2       (32GB)  (CameraKit)              0.3445              0.0370   0.0175
# 3  (CameraKit)       (32GB)              0.0370              0.3445   0.0175
# 4       (32GB)       (Case)              0.3445              0.2145   0.1025
#
#    confidence      lift  leverage  conviction  zhangs_metric
# 0    0.488479  1.028377  0.001462    1.026351       0.030953
# 1    0.111579  1.028377  0.001462    1.003466       0.052561
# 2    0.050798  1.372926  0.004754    1.014537       0.414384
# 3    0.472973  1.372926  0.004754    1.243769       0.282065
# 4    0.297533  1.387099  0.028605    1.118201       0.425737

# %%
# Display the top rules
rules.sort_values(["support", "confidence","lift"],axis = 0, ascending = False).head(8)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents      consequents  antecedent support  consequent support  \
# 91       (Speakers)  (RetinaDisplay)              0.2760              0.4230
# 90  (RetinaDisplay)       (Speakers)              0.4230              0.2760
# 11           (32GB)  (RetinaDisplay)              0.3445              0.4230
# 10  (RetinaDisplay)           (32GB)              0.4230              0.3445
# 71       (Cellular)  (RetinaDisplay)              0.2475              0.4230
# 70  (RetinaDisplay)       (Cellular)              0.4230              0.2475
# 93          (Stand)  (RetinaDisplay)              0.2410              0.4230
# 92  (RetinaDisplay)          (Stand)              0.4230              0.2410
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 91   0.1950    0.706522  1.670264  0.078252    1.966074       0.554271
# 90   0.1950    0.460993  1.670264  0.078252    1.343211       0.695481
# 11   0.1810    0.525399  1.242078  0.035277    1.215758       0.297327
# 10   0.1810    0.427896  1.242078  0.035277    1.145771       0.337778
# 71   0.1650    0.666667  1.576044  0.060308    1.731000       0.485714
# 70   0.1650    0.390071  1.576044  0.060308    1.233750       0.633449
# 93   0.1625    0.674274  1.594028  0.060557    1.771427       0.490986
# 92   0.1625    0.384161  1.594028  0.060557    1.232464       0.645855
