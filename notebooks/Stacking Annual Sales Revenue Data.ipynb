# %% [markdown]
# ##Business Analytics and Data Visualization
# ###Prof. Jose Mendoza
#
# Chapter 4 - Exercise 30
#
# File: vandykeunstacked_r.csv

# %%
# Import file
import pandas as pd
vandyke = pd.read_csv('vandykeunstacked_r.csv')
vandyke.head()
# Out:
#    Year    QTR1    QTR2  QTR3  QTR4
# 0     1    $562    $577  $578  $526
# 1     2    $599    $829  $578  $748
# 2     3    $735    $644  $639  $748
# 3     4    $785    $870  $861  $526
# 4     5  $1,228  $1,317  $841  $979

# %%
# Stacking vandyke

vandyke_stacked = vandyke.stack()
print(vandyke_stacked)
# Out:
# 0  Year         1
#    QTR1      $562
#    QTR2      $577
#    QTR3      $578
#    QTR4      $526
# 1  Year         2
#    QTR1      $599
#    QTR2      $829
#    QTR3      $578
#    QTR4      $748
# 2  Year         3
#    QTR1      $735
#    QTR2      $644
#    QTR3      $639
#    QTR4      $748
# 3  Year         4
#    QTR1      $785
#    QTR2      $870
#    QTR3      $861
#    QTR4      $526
# 4  Year         5
#    QTR1    $1,228
#    QTR2    $1,317
#    QTR3      $841
#    QTR4      $979
# dtype: object

# %%
# Saving the file
vandyke_stacked.to_csv('vandykestacked_r.csv')
